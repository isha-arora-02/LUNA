# %%
import pandas as pd

# %%
f = pd.read_csv("gene_expr_data/mergedExpr.csv", index_col=0)

# %%
example1 = f.iloc[:1, :]

# %%
example1
# Out:
#                 RBP7       PGD    UBIAD1    AGTRAP   TNFRSF8      ALPL  \
# GSM4210123  4.958472  7.689553  6.431265  6.701697  5.320632  7.540836
#
#              LDLRAP1      NUDC   PHACTR4     TXLNA  ...      XBP1     AP1B1  \
# GSM4210123  6.881013  5.522178  5.895283  5.812946  ...  6.046271  5.880048
#
#                SF3A1      CBX6     TCF20      BRD1     MTMR3     TOP3B  \
# GSM4210123  7.172882  6.094148  6.154447  5.763828  6.814271  5.688114
#
#               SNRPD3     THOC5
# GSM4210123  5.910768  6.274615
#
# [1 rows x 663 columns]

# %%
example1.to_csv("example_test.csv")
